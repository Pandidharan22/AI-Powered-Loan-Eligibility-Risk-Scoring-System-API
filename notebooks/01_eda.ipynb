# %%
import pandas as pd

df = pd.read_excel("../data/raw/6S_AI_TASK-Loan_default_Loan_default.xlsx")
df.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# ...

# %%
df.shape
# Out:
# (255246, 18)

# %%
df.columns
# Out:
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus',
#        'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner',
#        'Default'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 255246 entries, 0 to 255245
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255246 non-null  str
#  1   Age             255246 non-null  int64
#  2   Income          255246 non-null  int64
#  3   LoanAmount      255246 non-null  int64
#  4   CreditScore     255246 non-null  int64
#  5   MonthsEmployed  255246 non-null  int64
#  6   NumCreditLines  255246 non-null  int64
#  7   InterestRate    255246 non-null  float64
#  8   LoanTerm        255246 non-null  int64
#  9   DTIRatio        255246 non-null  float64
#  10  Education       255246 non-null  str
#  11  EmploymentType  255246 non-null  str
#  12  MaritalStatus   255246 non-null  str
#  13  HasMortgage     255246 non-null  str
#  14  HasDependents   255246 non-null  str
#  15  LoanPurpose     255246 non-null  str
#  16  HasCoSigner     255246 non-null  str
# ...

# %%
df.describe()
# Out:
#                  Age         Income     LoanAmount    CreditScore  \
# count  255246.000000  255246.000000  255246.000000  255246.000000
# mean       43.497434   82500.901475  127575.988881     574.269317
# std        14.990177   38963.557261   70842.305278     158.902794
# min        18.000000   15000.000000    5000.000000     300.000000
# 25%        31.000000   48826.000000   66147.250000     437.000000
# 50%        43.000000   82469.500000  127553.000000     574.000000
# 75%        56.000000  116222.250000  188980.750000     712.000000
# max        69.000000  149999.000000  249999.000000     849.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   255246.000000   255246.000000  255246.000000  255246.000000
# mean        59.543311        2.501081      13.492789      36.025716
# std         34.642822        1.117015       6.636541      16.969363
# min          0.000000        1.000000       2.000000      12.000000
# ...

# %%
df.isnull().sum()
# Out:
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %% [markdown]
# TARGET DISTRIBUTION ANALYSIS

# %%
df['Default'].value_counts()
df['Default'].value_counts(normalize=True)
# Out:
# Default
# 0    0.883861
# 1    0.116139
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Default', data=df)
plt.title("Target Distribution - Default VS Non-Default")
plt.show()

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
# Numerical features distribution
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

df[num_cols].hist(figsize=(15, 10), bins=30)
plt.tight_layout()
plt.show()

# %%
df['Age'].hist(bins=100)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution")
plt.show()

# %%
df['Income'].hist(bins=200)
plt.xlabel("Income")
plt.ylabel("Frequency")
plt.title("Income Distribution")
plt.show()

# %%
df['LoanAmount'].hist(bins=200)
plt.xlabel("Loan Amount")
plt.ylabel("Frequency")
plt.title("Loan Amount Distribution")
plt.show()

# %%
df['CreditScore'].hist(bins=200)
plt.xlabel("Credit Score")
plt.ylabel("Frequency")
plt.title("Credit Score Distribution")
plt.show()

# %%
df['MonthsEmployed'].hist(bins=100)
plt.xlabel("Months Employed")  
plt.ylabel("Frequency")
plt.title("Months Employed Distribution")
plt.show()

# %%
df['NumCreditLines'].hist(bins=30)
plt.xlabel("Number of Credit Lines")
plt.ylabel("Frequency")
plt.title("Number of Credit Lines Distribution")
plt.show()

# %%
df['InterestRate'].hist(bins=100)
plt.xlabel("Interest Rate") 
plt.ylabel("Frequency")
plt.title("Interest Rate Distribution") 
plt.show()

# %%
df['LoanTerm'].hist(bins=30)
plt.xlabel("Loan Term (Months)")
plt.ylabel("Frequency")
plt.title("Loan Term Distribution")
plt.show()

# %%
df['DTIRatio'].hist(bins=100)
plt.xlabel("DTI Ratio")     
plt.ylabel("Frequency")
plt.title("DTI Ratio Distribution")
plt.show()

# %%
# Categorical features distribution
cat_cols = df.select_dtypes(include=['object']).columns 

for col in cat_cols:
    print(f"{df[col].value_counts()}\n")
# Out:
# C:\Users\pandi\AppData\Local\Temp\ipykernel_7096\407702431.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include=['object']).columns
# LoanID
# I38PQUQS96    1
# HPSK72WA7R    1
# C1OZ6DPJ8Y    1
# V2KKSFM3UN    1
# EY08JDHTZP    1
#              ..
# SNJ7HKIR0P    1
# PRF588IALO    1
# EONXGLYH2P    1
# WAR5W2QB6M    1
# BDMZ1E9FRD    1
# Name: count, Length: 255246, dtype: int64
#
# Education
# Bachelor's     64343
# High School    63877
# Master's       63516
# PhD            63510
# Name: count, dtype: int64
#
# EmploymentType
# ...
